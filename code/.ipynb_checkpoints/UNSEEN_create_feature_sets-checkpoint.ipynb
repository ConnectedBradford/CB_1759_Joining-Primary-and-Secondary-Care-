# %% [markdown]
# # Create feature sets.
#
# The purpose of this notebook is to call all the notebooks that contribute to creating the features.

# %%
# Initial, major query of the databse.
# %run "UNSEEN_create_feature_sets_base.ipynb"
# Out:
# Stored 'feature_set_array' (DataFrame)
# The standard deviation of the mutual information scores is 0.0025.
# The interquartile range of the mutual information scores is 0.0035.
# The standard deviation of the scaled mutual information scores is 0.0249.
# The interquartile range of the scaled mutual information scores is 0.0356.
#     n_occurrences  n_patients_with_n_occurrences_in_a_year
# 0               1                                  1796571
# 1               2                                   593937
# 2               3                                   186502
# 3               4                                   109155
# 4               5                                    41250
# ..            ...                                      ...
# 93            110                                        2
# 94            124                                        1
# 95            132                                        1
# 96            135                                        1
# 97            150                                        1
#
# [98 rows x 2 columns]

# %%
# Append feature sets that are calculated from the base.
# %run "UNSEEN_create_feature_sets_appendix1.ipynb"
# Out:
# Stored 'feature_set_array' (DataFrame)

# %%
# Append feature sets that are based on entropy statistics.
# %run "UNSEEN_create_feature_sets_appendix2.ipynb"
# Out:
# Stored 'bq_countAppointmentsPerQuarter' (DataFrame)
# Stored 'bq_countDNAsPerQuarter' (DataFrame)
#   0%|          | 0/148122 [00:00<?, ? patients/s]
# It took 6040.788062572479 to process.
# A total of 4 patients had more than 72 events in a given quarter, thus requiring capping at 72, for that quarter
# Stored 'entropyBasedFS' (DataFrame)
# Stored 'feature_set_array' (DataFrame)

# %%
# Append feature sets that are collations of oter feature sets.
# %run "UNSEEN_create_feature_sets_appendix3.ipynb"
# Out:
# Stored 'nafsm_family_membership' (DataFrame)

# %%
# Append feature sets that are combinations of the collations.
# %run "UNSEEN_create_feature_sets_appendix4.ipynb"
# Out:
# Stored 'family_combins' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3338.3108084201813 to process.
# 31170 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 18830 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output1' (list)
# Stored 'discarded_because_only_one_value1' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3440.7208976745605 to process.
# 34640 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 15360 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output2' (list)
# Stored 'discarded_because_only_one_value2' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3614.796552658081 to process.
# 37062 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 12938 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output3' (list)
# Stored 'discarded_because_only_one_value3' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3483.8100864887238 to process.
# 35659 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 14341 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output4' (list)
# Stored 'discarded_because_only_one_value4' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3573.402217388153 to process.
# 35961 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 14039 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output5' (list)
# Stored 'discarded_because_only_one_value5' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3458.6940994262695 to process.
# 34934 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 15066 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output6' (list)
# Stored 'discarded_because_only_one_value6' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3615.7162625789642 to process.
# 36758 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 13242 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output7' (list)
# Stored 'discarded_because_only_one_value7' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3483.2170355319977 to process.
# 35524 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 14476 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output8' (list)
# Stored 'discarded_because_only_one_value8' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3539.849593400955 to process.
# 0 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 14384 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output9' (list)
# Stored 'discarded_because_only_one_value9' (list)
#   0%|          | 0/50000 [00:00<?, ? feature sets/s]
# It took 3333.3529031276703 to process.
# 0 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 15003 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output10' (list)
# Stored 'discarded_because_only_one_value10' (list)
#   0%|          | 0/59872 [00:00<?, ? feature sets/s]
# It took 4103.997289180756 to process.
# 0 feature sets contained sufficient information to be evaluated.
# These feature sets' evaluation statistics can be viewed in the `ls_output` variable.
#
# 14112 feature sets were discarded because they only presented one value for all patients.
# These discards can be viewed in the `discarded_because_only_one_value` variable.
# Stored 'ls_output11' (list)
# Stored 'discarded_because_only_one_value11' (list)
# Stored 'ls_output_family_combins' (list)
# Stored 'discarded_because_only_one_value' (set)

# %% [markdown]
# ## Show feature names.
#
# Below I print the names of the features that are in `feature_set_array`. Most feature sets that I evaluate are combinations of these feature sets, as explained in `UNSEEN_create_feature_sets_appendix3.ipynb` and `UNSEEN_create_feature_sets_appendix4.ipynb`.

# %%
# %store -r
print(f'The feature sets are {list(feature_set_array.columns)}')
# Out:
# The feature sets are ['person_id', 'abandonment_CYP', 'abandonment_EA', 'abandonment_Adult', 'ADHD_CYP', 'ADHD_EA', 'ADHD_Adult', 'adultVictimOfAbuse', 'firstAdmissionToPsychRehabServicesBefore30', 'agorophobia_CYPA', 'agorophobia_EA', 'agorophobia_Adult', 'alcoholMisuse_CYPA', 'alcoholMisuse_EA', 'alcoholMisuse_Adult', 'anxietyOrPanic_CYPA', 'anxietyOrPanic_EA', 'anxietyOrPanic_Adult', 'asylumSeeker_CYPA', 'asylumSeeker_EA', 'asylumSeeker_Adult', 'attemptedSuicide_CYPA', 'attemptedSuicide_EA', 'attemptedSuicide_Adult', 'auditoryHallucinations_CYPA', 'auditoryHallucinations_EA', 'auditoryHallucinations_Adult', 'autism_CYPA', 'autism_EA', 'autism_Adult', 'bodyDysmorphicDisorder_CYPA', 'bodyDysmorphicDisorder_EA', 'bodyDysmorphicDisorder_Adult', 'brainInjury_CYPA', 'brainInjury_EA', 'brainInjury_Adult', 'CAMHSrefsAndDisch_CYPA', 'CAMHSrefsAndDisch_EA', 'childAbuse', 'childProtection', 'countAppointmentsPreviousYear', 'countDNAsPreviousYear', 'ratioDNAtoAppointmentPreviousYear', 'countPsychologicalDisorders', 'crisisContraceptionCYP', 'CYPmentalDisorder', 'CYPneurodevDisorder', 'depressionNotDysthymiaOrChronic_CYPA', 'depressionNotDysthymiaOrChronic_EA', 'depressionNotDysthymiaOrChronic_Adult', 'dissociation_CYPA', 'dissociation_EA', 'dissociation_Adult', 'drugMisuse_CYPA', 'drugMisuse_EA', 'drugMisuse_Adult', 'eatingDisorders_CYPA', 'eatingDisorders_EA', 'eatingDisorders_Adult', 'extremeSelfNeglect', 'familialMentalHealthConditions', 'familialSubstanceMisuse', 'familyHistoryOfAlcoholism', 'familyHistoryOfPsychosis', 'foodInsecurity_CYPA', 'foodInsecurity_EA', 'foodInsecurity_Adult', 'historyOfOrCurrentAddiction', 'hoarder_CYPA', 'hoarder_EA', 'hoarder_Adult', 'homeless_CYPA', 'homeless_EA', 'homeless_Adult', 'IAPTreferral_CYPA', 'IAPTreferral_EA', 'IAPTreferral_Adult', 'IAPTrevolvingDoor_CYPA', 'IAPTrevolvingDoor_EA', 'IAPTrevolvingDoor_Adult', 'IAPTuse_CYPA', 'IAPTuse_EA', 'IAPTuse_Adult', 'incarcerationImprisonment_CYPA', 'incarcerationImprisonment_EA', 'incarcerationImprisonment_Adult', 'manyDNA_CYPA', 'manyDNA_EA', 'manyDNA_Adult', 'medianAnnualCountAppointments', 'medianAnnualCountAppointments_CYPA', 'medianAnnualCountAppointments_EA', 'medianAnnualCountAppointments_Adult', 'medianAnnualCountDNAs', 'medianAnnualCountDNAs_CYPA', 'medianAnnualCountDNAs_EA', 'medianAnnualCountDNAs_Adult', 'medianAnnualRatioDNAtoAppointment', 'medianAnnualRatioDNAtoAppointment_CYPA', 'medianAnnualRatioDNAtoAppointment_EA', 'medianAnnualRatioDNAtoAppointment_Adult', 'metabolicSyndrome_CYPA', 'metabolicSyndrome_EA', 'metabolicSyndrome_Adult', 'NESA_CYPA', 'NESA_EA', 'NESA_Adult', 'nonNativeEnglishSpeaker', 'OCD_CYPA', 'OCD_EA', 'OCD_Adult', 'paranoia_CYPA', 'paranoia_EA', 'paranoia_Adult', 'partedParents', 'poorBodyImage_CYPA', 'poorBodyImage_EA', 'poorBodyImage_Adult', 'poverty_CYPA', 'poverty_EA', 'poverty_Adult', 'raisedInCareSystem', 'relevantPrescriptions_CYPA', 'relevantPrescriptions_EA', 'relevantPrescriptions_Adult', 'schoolRefusal', 'selfHarm_CYPA', 'selfHarm_EA', 'selfHarm_Adult', 'sleepDisturbance_CYPA', 'sleepDisturbance_EA', 'sleepDisturbance_Adult', 'sleepDysfunction_CYPA', 'sleepDysfunction_EA', 'sleepDysfunction_Ault', 'socialServicesInvolved_CYPA', 'socialServicesInvolved_EA', 'socialServicesInvolved_Adult', 'socialServicesInvolvedCountOfCodes_CYPA', 'socialServicesInvolvedCountOfCodes_EA', 'socialServicesInvolvedCountOfCodes_Adult', 'SpLD_CYPA', 'SpLD_EA', 'SpLD_Adult', 'substanceMisuse_CYPA', 'substanceMisuse_EA', 'substanceMisuse_Adult', 'suicidal_CYPA', 'suicidal_EA', 'suicidal_Adult', 'teenagePregnancy', 'tinnitus_CYPA', 'tinnitus_EA', 'tinnitus_Adult', 'tortured_CYPA', 'tortured_EA', 'tortured_Adult', 'trafficked_CYPA', 'trafficked_EA', 'trafficked_Adult', 'UPSI_CYPA', 'UPSI_EA', 'UPSI_Adult', 'violentBehaviour_CYPA', 'violentBehaviour_EA', 'violentBehaviour_Adult', 'mentalHealthConcern_CYPA', 'mentalHealthConcern_EA', 'mentalHealthConcern_Adult', 'FamilyConcerns', 'recurrentEDattendances_CYPA', 'recurrentEDattendances_EA', ...
